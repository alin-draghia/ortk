# %%
# %pylab inline
import sys, os
sys.path.append('../bin')
os.environ['PATH'] += (';../3rd-party/opencv/x64/vc12/bin')
os.environ['PATH'] += (';../packages/boost_serialization-vc120.1.55.0.16/lib/native/address-model-64/lib')
import cv2
import pickle
import pprint
import inspect
import object_recognition_toolkit as ort
import skimage.data, skimage.feature
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
image = cv2.imread(r'..\datasets\INRIAPerson\test_64x128_H96\pos\crop_000001a.png', cv2.IMREAD_GRAYSCALE)

# %%
print image.shape
print image.dtype
print min(image.ravel())
print max(image.ravel())
# Out:
# (134L, 70L)
# uint8
# 13
# 227

# %%
im = image[3:3+64,3:3+64]

# %%
im.shape
# Out:
# (64L, 64L)

# %%
sk_feats, sk_viz = skimage.feature.hog(im, cells_per_block=(2,2), visualise=True, normalise=True)

# %%
sk_feats.shape
# Out:
# (1764L,)

# %%
my_hog = ort.HogFeatureExtractor(ort.Size(64,64), 
                                 ort.Size(16,16), 
                                 ort.Size(8,8), 
                                 ort.Size(8,8),
                                 9)

# %%
my_hog.Lenght()
# Out:
# 1764

# %%
my_feats = my_hog.Compute(im)

# %%
my_feats= my_feats.ravel()
my_feats.shape
# Out:
# (1764L,)

# %%
allclose(sk_feats, my_feats)
# Out:
# False

# %%
sqrt(1764)
# Out:
# 42.0

# %%
imshow(sk_feats.reshape(42,42))

# %%
imshow(my_feats.reshape(42,42))
