# %%
from skimage.feature import hog
from skimage import data

# %%
im = data.camera()

# %%
feats, feats_viz = hog(im, cells_per_block=(2,2), visualise=True)

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
imshow(im, cmap='gray')

# %%
imshow(feats_viz)

# %%
roi = im[0:64,0:64]
roi.shape
# Out:
# (64L, 64L)

# %%
imshow(roi, cmap='gray')

# %%
roi_feats, roi_feats_viz = hog(roi, cells_per_block=(2,2), visualise=True)

# %%
imshow(roi_feats_viz)

# %%
roi_feats.shape
# Out:
# (1764L,)

# %%
feats.shape
# Out:
# (142884L,)

# %%
feats_ = feats.reshape(63,63,36)

# %%
feats__ = feats_[0:7,0:7, :]

# %%
feats__.ravel().shape
# Out:
# (1764L,)

# %%
roi_feats_ = feats__.ravel()

# %%
allclose(roi_feats, roi_feats_, rtol=1e-1, atol=1e-1)
# Out:
# True

# %%
sum(roi_feats)
# Out:
# 48.99999552924082

# %%
sum(roi_feats_)
# Out:
# 48.99999560059068

# %%
roi_feats
# Out:
# array([  6.59550742e-02,   4.15392555e-02,   2.79823681e-02, ...,
#          2.72664437e-02,   1.07780082e-02,  -8.56216752e-18])

# %%
roi_feats_
# Out:
# array([  6.59550742e-02,   4.15392555e-02,   2.79823681e-02, ...,
#          4.66833300e-02,   1.52342858e-02,  -1.00852359e-17])

# %%
imshow(roi_feats_viz)

# %%
imshow(feats_viz[:64,:64])

# %%
allclose(roi_feats, roi_feats_, rtol=1e-1, atol=1e-1)
# Out:
# True

# %%
imshow(roi_feats.reshape(42,42))

# %%
imshow(roi_feats_.reshape(42,42))

# %%
a = roi_feats.reshape(42,42)
b = roi_feats_.reshape(42,42)
d = a - b
imshow(d)

# %%
import cv2

# %%
import sys

# %%
sys.path.append('../bin/')

# %%
import object_recognition_toolkit_ext
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-4-f4e49fa6da58> in <module>()
# ----> 1 import object_recognition_toolkit_ext
#
# ImportError: DLL load failed: The specified module could not be found.

# %%
cd ../bin
# Out:
# d:\DEV.0\object-recognition-toolkit\vs_proj\bin

# %%
import object_recognition_toolkit_ext
from object_recognition_toolkit_ext import Size

# %%
object_recognition_toolkit_ext.HogFeatureExtractor(Size(512,512), Size(8,8), Size(8,8), Size(16,1
